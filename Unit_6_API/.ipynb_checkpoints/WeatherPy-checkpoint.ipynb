# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint
import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
link = "http://api.openweathermap.org/data/2.5/weather?"
link =f"{link}appid={api_key}&units=metric&q="

#set up lists hold data
location =[]
clouds = []
country = []
date = []
humidity = []
lats = []
lngs = []
max_temp = []
wind = []

#set organizational variables
count = 0
current_set = 1

#collect data and store in lists
print("Beginning Data Retrieval\n-----------------------------")
for city in cities:
   try:
       data = requests.get(link+city).json()
       location.append(data["name"])
       clouds.append(data["clouds"]["all"])
       country.append(data["sys"]["country"])
       date.append(datetime.date.fromtimestamp(data["dt"]))
       humidity.append(data["main"]["humidity"])
       lats.append(data["coord"]["lat"])
       lngs.append(data["coord"]["lon"])
       max_temp.append(data["main"]["temp_max"])
       wind.append(data["wind"]["speed"])
       if count > 49:
           count = 1
           current_set += 1
       else:
           count += 1
       print(f"Processing record {count} of set {current_set} | {city}")
   except Exception:
       print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 1 of set 1 | cabo san lucas
# Processing record 2 of set 1 | yellowknife
# Processing record 3 of set 1 | rikitea
# Processing record 4 of set 1 | havelock
# Processing record 5 of set 1 | opole lubelskie
# Processing record 6 of set 1 | punta arenas
# City not found. Skipping...
# Processing record 7 of set 1 | paris
# Processing record 8 of set 1 | umm lajj
# Processing record 9 of set 1 | cape town
# Processing record 10 of set 1 | trincomalee
# Processing record 11 of set 1 | qaanaaq
# City not found. Skipping...
# Processing record 12 of set 1 | tefe
# Processing record 13 of set 1 | tessalit
# Processing record 14 of set 1 | namibe
# Processing record 15 of set 1 | arraial do cabo
# Processing record 16 of set 1 | mareeba
# Processing record 17 of set 1 | khatanga
# Processing record 18 of set 1 | torbay
# Processing record 19 of set 1 | buraydah
# Processing record 20 of set 1 | port blair
# Processing record 21 of set 1 | grindavik
# Processing record 22 of set 1 | georgetown
# City not found. Skipping...
# Processing record 23 of set 1 | cayenne
# Processing record 24 of set 1 | kavaratti
# Processing record 25 of set 1 | bubaque
# Processing record 26 of set 1 | mae sai
# Processing record 27 of set 1 | nalut
# Processing record 28 of set 1 | albany
# Processing record 29 of set 1 | avarua
# Processing record 30 of set 1 | atuona
# Processing record 31 of set 1 | shache
# Processing record 32 of set 1 | bredasdorp
# Processing record 33 of set 1 | riverton
# Processing record 34 of set 1 | barrow
# Processing record 35 of set 1 | okhotsk
# Processing record 36 of set 1 | paamiut
# Processing record 37 of set 1 | quatre cocos
# Processing record 38 of set 1 | tasiilaq
# City not found. Skipping...
# Processing record 39 of set 1 | codrington
# Processing record 40 of set 1 | busselton
# Processing record 41 of set 1 | ancud
# Processing record 42 of set 1 | kruisfontein
# Processing record 43 of set 1 | flagstaff
# Processing record 44 of set 1 | mataura
# Processing record 45 of set 1 | grand-santi
# Processing record 46 of set 1 | amarante do maranhao
# Processing record 47 of set 1 | tiksi
# Processing record 48 of set 1 | atambua
# Processing record 49 of set 1 | kapaa
# Processing record 50 of set 1 | safford
# Processing record 1 of set 2 | guatire
# Processing record 2 of set 2 | avera
# Processing record 3 of set 2 | tuktoyaktuk
# Processing record 4 of set 2 | narsaq
# Processing record 5 of set 2 | anadyr
# Processing record 6 of set 2 | clyde river
# Processing record 7 of set 2 | pansemal
# Processing record 8 of set 2 | hobart
# Processing record 9 of set 2 | san quintin
# Processing record 10 of set 2 | hermanus
# Processing record 11 of set 2 | lebu
# Processing record 12 of set 2 | nauta
# Processing record 13 of set 2 | jalu
# City not found. Skipping...
# Processing record 14 of set 2 | jamestown
# Processing record 15 of set 2 | izhma
# Processing record 16 of set 2 | timra
# Processing record 17 of set 2 | ushuaia
# Processing record 18 of set 2 | srandakan
# Processing record 19 of set 2 | takoradi
# Processing record 20 of set 2 | east london
# City not found. Skipping...
# Processing record 21 of set 2 | saint anthony
# Processing record 22 of set 2 | port elizabeth
# City not found. Skipping...
# Processing record 23 of set 2 | aklavik
# Processing record 24 of set 2 | vaini
# Processing record 25 of set 2 | bethel
# Processing record 26 of set 2 | cherskiy
# Processing record 27 of set 2 | svetlogorsk
# Processing record 28 of set 2 | mount isa
# Processing record 29 of set 2 | kohlu
# Processing record 30 of set 2 | ochakiv
# City not found. Skipping...
# Processing record 31 of set 2 | los llanos de aridane
# Processing record 32 of set 2 | seoul
# Processing record 33 of set 2 | provideniya
# Processing record 34 of set 2 | bluff
# Processing record 35 of set 2 | bambous virieux
# Processing record 36 of set 2 | ponta do sol
# Processing record 37 of set 2 | batemans bay
# Processing record 38 of set 2 | plouzane
# Processing record 39 of set 2 | upernavik
# Processing record 40 of set 2 | iquique
# Processing record 41 of set 2 | renqiu
# Processing record 42 of set 2 | zhigansk
# City not found. Skipping...
# Processing record 43 of set 2 | camara de lobos
# Processing record 44 of set 2 | diamantino
# Processing record 45 of set 2 | kharan
# Processing record 46 of set 2 | tuatapere
# Processing record 47 of set 2 | thompson
# Processing record 48 of set 2 | selikhino
# Processing record 49 of set 2 | bathsheba
# Processing record 50 of set 2 | mackay
# Processing record 1 of set 3 | kortkeros
# Processing record 2 of set 3 | karratha
# Processing record 3 of set 3 | lorengau
# Processing record 4 of set 3 | luderitz
# Processing record 5 of set 3 | saint-philippe
# Processing record 6 of set 3 | makakilo city
# Processing record 7 of set 3 | new norfolk
# Processing record 8 of set 3 | katsuura
# Processing record 9 of set 3 | bedesa
# Processing record 10 of set 3 | port hedland
# City not found. Skipping...
# Processing record 11 of set 3 | port alfred
# Processing record 12 of set 3 | vila franca do campo
# Processing record 13 of set 3 | yerbogachen
# Processing record 14 of set 3 | beira
# Processing record 15 of set 3 | sao joao da barra
# Processing record 16 of set 3 | kahului
# Processing record 17 of set 3 | piquete
# City not found. Skipping...
# Processing record 18 of set 3 | vilcun
# Processing record 19 of set 3 | burlington
# City not found. Skipping...
# Processing record 20 of set 3 | am timan
# City not found. Skipping...
# Processing record 21 of set 3 | abu kamal
# Processing record 22 of set 3 | chapais
# Processing record 23 of set 3 | lensk
# Processing record 24 of set 3 | lagoa
# Processing record 25 of set 3 | gamba
# Processing record 26 of set 3 | rajshahi
# City not found. Skipping...
# City not found. Skipping...
# Processing record 27 of set 3 | berdigestyakh
# Processing record 28 of set 3 | teya
# Processing record 29 of set 3 | airai
# Processing record 30 of set 3 | mount gambier
# Processing record 31 of set 3 | carnarvon
# City not found. Skipping...
# Processing record 32 of set 3 | calbuco
# Processing record 33 of set 3 | nikolskoye
# City not found. Skipping...
# Processing record 34 of set 3 | santa maria
# Processing record 35 of set 3 | meulaboh
# Processing record 36 of set 3 | katherine
# Processing record 37 of set 3 | alofi
# Processing record 38 of set 3 | vila velha
# City not found. Skipping...
# Processing record 39 of set 3 | shellbrook
# Processing record 40 of set 3 | verkhoyansk
# Processing record 41 of set 3 | butaritari
# Processing record 42 of set 3 | tromso
# Processing record 43 of set 3 | eyl
# Processing record 44 of set 3 | amberg
# City not found. Skipping...
# City not found. Skipping...
# Processing record 45 of set 3 | ilulissat
# Processing record 46 of set 3 | taltal
# Processing record 47 of set 3 | danielskuil
# Processing record 48 of set 3 | jining
# Processing record 49 of set 3 | aswan
# Processing record 50 of set 3 | saint-augustin
# Processing record 1 of set 4 | kodiak
# Processing record 2 of set 4 | te anau
# Processing record 3 of set 4 | hobyo
# Processing record 4 of set 4 | yantal
# City not found. Skipping...
# Processing record 5 of set 4 | klaksvik
# Processing record 6 of set 4 | greensboro
# City not found. Skipping...
# Processing record 7 of set 4 | linxia
# Processing record 8 of set 4 | cidreira
# Processing record 9 of set 4 | gulf gate estates
# Processing record 10 of set 4 | sorland
# Processing record 11 of set 4 | mwaro
# City not found. Skipping...
# Processing record 12 of set 4 | venice
# Processing record 13 of set 4 | souillac
# Processing record 14 of set 4 | saint-louis
# Processing record 15 of set 4 | natal
# Processing record 16 of set 4 | dowa
# Processing record 17 of set 4 | iqaluit
# Processing record 18 of set 4 | dikson
# Processing record 19 of set 4 | charlestown
# Processing record 20 of set 4 | coquimbo
# City not found. Skipping...
# Processing record 21 of set 4 | tigzirt
# City not found. Skipping...
# Processing record 22 of set 4 | quesnel
# Processing record 23 of set 4 | arkhangelskoye
# Processing record 24 of set 4 | launceston
# Processing record 25 of set 4 | tevaitoa
# Processing record 26 of set 4 | ballina
# Processing record 27 of set 4 | toamasina
# Processing record 28 of set 4 | nenjiang
# Processing record 29 of set 4 | ostrovnoy
# Processing record 30 of set 4 | baykit
# Processing record 31 of set 4 | port lincoln
# Processing record 32 of set 4 | victoria
# Processing record 33 of set 4 | kinsale
# Processing record 34 of set 4 | muisne
# Processing record 35 of set 4 | lompoc
# Processing record 36 of set 4 | ust-kuyga
# Processing record 37 of set 4 | toyooka
# Processing record 38 of set 4 | winchester
# Processing record 39 of set 4 | mar del plata
# Processing record 40 of set 4 | half moon bay
# Processing record 41 of set 4 | lusambo
# Processing record 42 of set 4 | beringovskiy
# City not found. Skipping...
# Processing record 43 of set 4 | talnakh
# Processing record 44 of set 4 | terrace
# Processing record 45 of set 4 | flinders
# Processing record 46 of set 4 | kuryk
# Processing record 47 of set 4 | newnan
# City not found. Skipping...
# Processing record 48 of set 4 | severo-kurilsk
# Processing record 49 of set 4 | staryy nadym
# Processing record 50 of set 4 | dunedin
# Processing record 1 of set 5 | havre-saint-pierre
# Processing record 2 of set 5 | thoen
# Processing record 3 of set 5 | kiama
# Processing record 4 of set 5 | norman wells
# Processing record 5 of set 5 | khandbari
# Processing record 6 of set 5 | longyearbyen
# Processing record 7 of set 5 | garowe
# Processing record 8 of set 5 | fortuna
# Processing record 9 of set 5 | binga
# Processing record 10 of set 5 | mahebourg
# City not found. Skipping...
# Processing record 11 of set 5 | anzio
# Processing record 12 of set 5 | tabuk
# Processing record 13 of set 5 | bilibino
# Processing record 14 of set 5 | castro
# Processing record 15 of set 5 | hilo
# Processing record 16 of set 5 | gaya
# Processing record 17 of set 5 | vangaindrano
# Processing record 18 of set 5 | tura
# Processing record 19 of set 5 | tete
# Processing record 20 of set 5 | pevek
# Processing record 21 of set 5 | fayaoue
# Processing record 22 of set 5 | najran
# Processing record 23 of set 5 | nieuw nickerie
# Processing record 24 of set 5 | leningradskiy
# Processing record 25 of set 5 | san carlos de bariloche
# City not found. Skipping...
# Processing record 26 of set 5 | prachuap khiri khan
# Processing record 27 of set 5 | adrar
# Processing record 28 of set 5 | geraldton
# Processing record 29 of set 5 | bad mergentheim
# Processing record 30 of set 5 | chokurdakh
# Processing record 31 of set 5 | edremit
# Processing record 32 of set 5 | muros
# Processing record 33 of set 5 | puerto ayora
# Processing record 34 of set 5 | nuuk
# City not found. Skipping...
# Processing record 35 of set 5 | la asuncion
# Processing record 36 of set 5 | puerto baquerizo moreno
# Processing record 37 of set 5 | naze
# Processing record 38 of set 5 | hithadhoo
# Processing record 39 of set 5 | pokhara
# Processing record 40 of set 5 | eureka
# City not found. Skipping...
# Processing record 41 of set 5 | san ignacio
# Processing record 42 of set 5 | chiang khong
# Processing record 43 of set 5 | mackenzie
# Processing record 44 of set 5 | santa fe
# Processing record 45 of set 5 | iralaya
# Processing record 46 of set 5 | kysyl-syr
# Processing record 47 of set 5 | bandrele
# Processing record 48 of set 5 | hamilton
# Processing record 49 of set 5 | miraflores
# Processing record 50 of set 5 | maniitsoq
# Processing record 1 of set 6 | tias
# City not found. Skipping...
# City not found. Skipping...
# Processing record 2 of set 6 | esperance
# Processing record 3 of set 6 | telciu
# Processing record 4 of set 6 | thinadhoo
# Processing record 5 of set 6 | chuy
# Processing record 6 of set 6 | mahajanga
# Processing record 7 of set 6 | san cristobal
# Processing record 8 of set 6 | iskilip
# Processing record 9 of set 6 | kununurra
# Processing record 10 of set 6 | faanui
# Processing record 11 of set 6 | montrose
# Processing record 12 of set 6 | zabol
# Processing record 13 of set 6 | gari
# Processing record 14 of set 6 | pangnirtung
# Processing record 15 of set 6 | shangrao
# Processing record 16 of set 6 | vestmannaeyjar
# Processing record 17 of set 6 | ribeira grande
# City not found. Skipping...
# Processing record 18 of set 6 | aksarka
# Processing record 19 of set 6 | maceio
# Processing record 20 of set 6 | egvekinot
# Processing record 21 of set 6 | shirokiy
# Processing record 22 of set 6 | lavrentiya
# Processing record 23 of set 6 | kupang
# Processing record 24 of set 6 | luanda
# Processing record 25 of set 6 | raudeberg
# Processing record 26 of set 6 | constitucion
# City not found. Skipping...
# Processing record 27 of set 6 | san patricio
# Processing record 28 of set 6 | hasaki
# Processing record 29 of set 6 | pangkalanbuun
# Processing record 30 of set 6 | wysokie mazowieckie
# Processing record 31 of set 6 | ust-tsilma
# Processing record 32 of set 6 | yar-sale
# Processing record 33 of set 6 | harper
# Processing record 34 of set 6 | adwa
# Processing record 35 of set 6 | bonthe
# Processing record 36 of set 6 | boca do acre
# Processing record 37 of set 6 | kavieng
# Processing record 38 of set 6 | husavik
# Processing record 39 of set 6 | kathmandu
# Processing record 40 of set 6 | portland
# Processing record 41 of set 6 | rundu
# City not found. Skipping...
# Processing record 42 of set 6 | pisco
# Processing record 43 of set 6 | wanning
# Processing record 44 of set 6 | raymond
# Processing record 45 of set 6 | panchagarh
# Processing record 46 of set 6 | taoudenni
# Processing record 47 of set 6 | tupik
# Processing record 48 of set 6 | rogatica
# City not found. Skipping...
# Processing record 49 of set 6 | belmonte
# Processing record 50 of set 6 | snyder
# Processing record 1 of set 7 | kieta
# Processing record 2 of set 7 | larvik
# Processing record 3 of set 7 | muborak
# Processing record 4 of set 7 | jinxiang
# Processing record 5 of set 7 | yelanskiy
# Processing record 6 of set 7 | dodoma
# Processing record 7 of set 7 | stepnogorsk
# City not found. Skipping...
# Processing record 8 of set 7 | agadez
# Processing record 9 of set 7 | havoysund
# Processing record 10 of set 7 | arlit
# Processing record 11 of set 7 | santiago del estero
# Processing record 12 of set 7 | shizunai
# Processing record 13 of set 7 | belyy yar
# Processing record 14 of set 7 | ust-ilimsk
# Processing record 15 of set 7 | vanimo
# Processing record 16 of set 7 | bowen
# City not found. Skipping...
# Processing record 17 of set 7 | noyabrsk
# Processing record 18 of set 7 | lexington
# Processing record 19 of set 7 | thunder bay
# Processing record 20 of set 7 | praia
# Processing record 21 of set 7 | baijiantan
# City not found. Skipping...
# Processing record 22 of set 7 | miquelon
# City not found. Skipping...
# Processing record 23 of set 7 | tiznit
# City not found. Skipping...
# Processing record 24 of set 7 | otjimbingwe
# Processing record 25 of set 7 | rio verde de mato grosso
# Processing record 26 of set 7 | mgandu
# City not found. Skipping...
# City not found. Skipping...
# Processing record 27 of set 7 | verkhovyna
# Processing record 28 of set 7 | high level
# Processing record 29 of set 7 | boyolangu
# Processing record 30 of set 7 | campestre
# Processing record 31 of set 7 | matagami
# Processing record 32 of set 7 | soweto
# Processing record 33 of set 7 | ornskoldsvik
# Processing record 34 of set 7 | xai-xai
# Processing record 35 of set 7 | coihaique
# Processing record 36 of set 7 | pacifica
# Processing record 37 of set 7 | vao
# Processing record 38 of set 7 | san martin
# Processing record 39 of set 7 | omsukchan
# Processing record 40 of set 7 | isla vista
# Processing record 41 of set 7 | vostok
# Processing record 42 of set 7 | cabedelo
# Processing record 43 of set 7 | bulgan
# Processing record 44 of set 7 | porto novo
# Processing record 45 of set 7 | vyartsilya
# Processing record 46 of set 7 | corn island
# City not found. Skipping...
# Processing record 47 of set 7 | waddan
# City not found. Skipping...
# Processing record 48 of set 7 | tayshet
# Processing record 49 of set 7 | nova olimpia
# City not found. Skipping...
# Processing record 50 of set 7 | mitchell
# Processing record 1 of set 8 | lao cai
# City not found. Skipping...
# Processing record 2 of set 8 | faya
# Processing record 3 of set 8 | diego de almagro
# Processing record 4 of set 8 | sao filipe
# Processing record 5 of set 8 | sari
# Processing record 6 of set 8 | kaduna
# City not found. Skipping...
# Processing record 7 of set 8 | palmer
# Processing record 8 of set 8 | cloquet
# Processing record 9 of set 8 | utiel
# Processing record 10 of set 8 | grand gaube
# Processing record 11 of set 8 | bar harbor
# Processing record 12 of set 8 | lewisporte
# Processing record 13 of set 8 | mezohegyes
# Processing record 14 of set 8 | ardakan
# Processing record 15 of set 8 | kholmogory
# Processing record 16 of set 8 | wageningen
# Processing record 17 of set 8 | rumoi
# City not found. Skipping...
# Processing record 18 of set 8 | shimoda
# Processing record 19 of set 8 | petropavlovsk-kamchatskiy
# Processing record 20 of set 8 | solnechnyy
# Processing record 21 of set 8 | atar
# Processing record 22 of set 8 | moree
# Processing record 23 of set 8 | lata
# Processing record 24 of set 8 | saskylakh
# Processing record 25 of set 8 | dryden
# City not found. Skipping...
# Processing record 26 of set 8 | rio gallegos
# Processing record 27 of set 8 | idlib
# Processing record 28 of set 8 | salalah
# Processing record 29 of set 8 | saint-pierre
# Processing record 30 of set 8 | haverfordwest
# City not found. Skipping...
# Processing record 31 of set 8 | sola
# City not found. Skipping...
# Processing record 32 of set 8 | store heddinge
# Processing record 33 of set 8 | poum
# Processing record 34 of set 8 | isangel
# Processing record 35 of set 8 | takaka
# Processing record 36 of set 8 | bati
# Processing record 37 of set 8 | kirakira
# Processing record 38 of set 8 | araceli
# City not found. Skipping...
# Processing record 39 of set 8 | kenai
# City not found. Skipping...
# Processing record 40 of set 8 | port-gentil
# City not found. Skipping...
# Processing record 41 of set 8 | kayerkan
# Processing record 42 of set 8 | ca mau
# Processing record 43 of set 8 | barra do garcas
# Processing record 44 of set 8 | dingle
# Processing record 45 of set 8 | kingsland
# Processing record 46 of set 8 | malie
# Processing record 47 of set 8 | lasa
# Processing record 48 of set 8 | poykovskiy
# Processing record 49 of set 8 | smirnykh
# Processing record 50 of set 8 | talaya
# Processing record 1 of set 9 | port hardy
# Processing record 2 of set 9 | muravlenko
# Processing record 3 of set 9 | maloy
# Processing record 4 of set 9 | auki
# Processing record 5 of set 9 | ambon
# Processing record 6 of set 9 | omboue
# Processing record 7 of set 9 | xichang
# Processing record 8 of set 9 | nakhon thai
# Processing record 9 of set 9 | fukue
# Processing record 10 of set 9 | hay river
# City not found. Skipping...
# Processing record 11 of set 9 | bonavista
# Processing record 12 of set 9 | kaili
# Processing record 13 of set 9 | olga
# Processing record 14 of set 9 | xiongyue
# Processing record 15 of set 9 | hami
# Processing record 16 of set 9 | beberibe
# Processing record 17 of set 9 | belaya gora
# Processing record 18 of set 9 | biograd na moru
# Processing record 19 of set 9 | caravelas
# Processing record 20 of set 9 | benjamin hill
# Processing record 21 of set 9 | hervey bay
# Processing record 22 of set 9 | waipawa
# Processing record 23 of set 9 | trairi
# Processing record 24 of set 9 | chilca
# Processing record 25 of set 9 | preili
# Processing record 26 of set 9 | marzuq
# Processing record 27 of set 9 | ahipara
# City not found. Skipping...
# Processing record 28 of set 9 | cockburn town
# Processing record 29 of set 9 | robertsport
# Processing record 30 of set 9 | la libertad
# City not found. Skipping...
# Processing record 31 of set 9 | tecoanapa
# Processing record 32 of set 9 | san pedro
# Processing record 33 of set 9 | kamaishi
# Processing record 34 of set 9 | ruski krstur
# Processing record 35 of set 9 | khorixas
# City not found. Skipping...
# Processing record 36 of set 9 | vagur
# Processing record 37 of set 9 | awjilah
# Processing record 38 of set 9 | mantua
# Processing record 39 of set 9 | severobaykalsk
# Processing record 40 of set 9 | dwarka
# Processing record 41 of set 9 | la ligua
# Processing record 42 of set 9 | madisonville
# Processing record 43 of set 9 | road town
# Processing record 44 of set 9 | sao felix do xingu
# Processing record 45 of set 9 | wakkanai
# Processing record 46 of set 9 | panama city
# Processing record 47 of set 9 | yulara
# Processing record 48 of set 9 | adre
# Processing record 49 of set 9 | tilichiki
# Processing record 50 of set 9 | inza
# Processing record 1 of set 10 | novikovo
# Processing record 2 of set 10 | hirara
# Processing record 3 of set 10 | hofn
# Processing record 4 of set 10 | vigrestad
# Processing record 5 of set 10 | obidos
# Processing record 6 of set 10 | rio bueno
# Processing record 7 of set 10 | jiexiu
# Processing record 8 of set 10 | sumbe
# Processing record 9 of set 10 | ejido
# Processing record 10 of set 10 | pochutla
# Processing record 11 of set 10 | erenhot
# Processing record 12 of set 10 | san luis
# Processing record 13 of set 10 | nagareyama
# Processing record 14 of set 10 | takapau
# Processing record 15 of set 10 | evanton
# Processing record 16 of set 10 | sfantu gheorghe
# Processing record 17 of set 10 | leh
# Processing record 18 of set 10 | svarstad
# Processing record 19 of set 10 | dicabisagan
# Processing record 20 of set 10 | bud
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing record 21 of set 10 | puerto escondido
# Processing record 22 of set 10 | cap malheureux
# City not found. Skipping...
# Processing record 23 of set 10 | sinnamary
# Processing record 24 of set 10 | acari
# Processing record 25 of set 10 | jian
# Processing record 26 of set 10 | acapulco
# Processing record 27 of set 10 | duku
# Processing record 28 of set 10 | kharabali
# Processing record 29 of set 10 | kwinana
# Processing record 30 of set 10 | komsomolskoye
# Processing record 31 of set 10 | salinopolis
# Processing record 32 of set 10 | sciacca
# Processing record 33 of set 10 | union
# Processing record 34 of set 10 | sambava
# Processing record 35 of set 10 | tual
# Processing record 36 of set 10 | cairns
# Processing record 37 of set 10 | gulariya
# Processing record 38 of set 10 | sao gabriel da cachoeira
# Processing record 39 of set 10 | oyama
# Processing record 40 of set 10 | kibre mengist
# Processing record 41 of set 10 | torring
# Processing record 42 of set 10 | nome
# Processing record 43 of set 10 | demidov
# Processing record 44 of set 10 | weligama
# Processing record 45 of set 10 | ukrayinka
# Processing record 46 of set 10 | haines junction
# Processing record 47 of set 10 | fare
# Processing record 48 of set 10 | kaitangata
# City not found. Skipping...
# Processing record 49 of set 10 | mayo
# Processing record 50 of set 10 | ilek
# Processing record 1 of set 11 | lillesand
# Processing record 2 of set 11 | jacareacanga
# Processing record 3 of set 11 | ahuimanu
# Processing record 4 of set 11 | chany
# Processing record 5 of set 11 | plettenberg bay
# Processing record 6 of set 11 | saint-paul
# Processing record 7 of set 11 | sotaquira
# Processing record 8 of set 11 | dawei
# Processing record 9 of set 11 | brainerd
# Processing record 10 of set 11 | evensk
# Processing record 11 of set 11 | kudal
# Processing record 12 of set 11 | mehamn
# City not found. Skipping...
# Processing record 13 of set 11 | oussouye
# City not found. Skipping...
# City not found. Skipping...
# Processing record 14 of set 11 | ewa beach
# Processing record 15 of set 11 | yuci
# Processing record 16 of set 11 | gallup
# Processing record 17 of set 11 | storforshei
# Processing record 18 of set 11 | dzilam gonzalez
# Processing record 19 of set 11 | ubinskoye
# City not found. Skipping...
# Processing record 20 of set 11 | amantea
# Processing record 21 of set 11 | yurty
# Processing record 22 of set 11 | vizinga
# Processing record 23 of set 11 | santa rosa
# Processing record 24 of set 11 | ukiah
# Processing record 25 of set 11 | west wendover
# Processing record 26 of set 11 | gambiran
# Processing record 27 of set 11 | saint-joseph
# Processing record 28 of set 11 | kihei
# City not found. Skipping...
# Processing record 29 of set 11 | tutoia
# Processing record 30 of set 11 | oromocto
# Processing record 31 of set 11 | laguna
# Processing record 32 of set 11 | coxim
# Processing record 33 of set 11 | kurilsk
# Processing record 34 of set 11 | kinkala
# Processing record 35 of set 11 | vidim
# Processing record 36 of set 11 | richards bay
# Processing record 37 of set 11 | bambanglipuro
# Processing record 38 of set 11 | zhuhai
# Processing record 39 of set 11 | kulhudhuffushi
# Processing record 40 of set 11 | pampierstad
# Processing record 41 of set 11 | sao sebastiao
# Processing record 42 of set 11 | guaraniacu
# Processing record 43 of set 11 | la paz
# Processing record 44 of set 11 | mayna
# Processing record 45 of set 11 | zavetnoye
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df ={"City":location,
     "Cloudiness": clouds,
     "Country": country,
     "Date": date,
     "Humidity": humidity,
     "Latitude": lats,
     "Longitude":lngs,
     "Max Temperature": max_temp,
     "Wind Speed": wind,
}
#convert to dataframe
df = pd.DataFrame(df)
df.count()
# Out:
# City               545
# Cloudiness         545
# Country            545
# Date               545
# Humidity           545
# Latitude           545
# Longitude          545
# Max Temperature    545
# Wind Speed         545
# dtype: int64

# %%
df.to_csv("_data/weather_data.csv")
df.head()
# Out:
#               City  Cloudiness Country        Date  Humidity  Latitude  \
# 0   Cabo San Lucas           5      MX  2019-09-26        65     22.89
# 1      Yellowknife          20      CA  2019-09-26        59     62.45
# 2          Rikitea          92      PF  2019-09-26        69    -23.12
# 3         Havelock           1      US  2019-09-26        74     34.88
# 4  Opole Lubelskie          90      PL  2019-09-26       100     51.15
#
#    Longitude  Max Temperature  Wind Speed
# 0    -109.91            30.00        7.20
# 1    -114.38             3.00        5.70
# 2    -134.97            22.20        4.61
# 3     -76.90            27.22        5.70
# 4      21.97            14.44        1.00

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#create a plot based on latitude and max temp
fig, ax = plt.subplots(figsize=(15,10))
ax.scatter(x=df["Latitude"], y=df["Max Temperature"])
#label graph
plt.title("Correlation of Latituted and Maximum Temperature", size=15)
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (Celcius)")
plt.grid()
#save as png
plt.savefig("_data/temp_scatter")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.scatter(x=df["Latitude"], y=df["Humidity"])
#label graph
plt.title("City Latitude vs. Humidity", size=15)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
#save as png
plt.savefig("_data/humidity_scatter")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.scatter(x=df["Latitude"], y=df["Cloudiness"])
#label graph
plt.title("City Latitude vs. Cloudiness", size=15)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
#save as png
plt.savefig("_data/cloudiness_scatter")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.scatter(x=df["Latitude"], y=df["Wind Speed"])
#label graph
plt.title("City Latitude vs. Wind Speed", size=15)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
#save as png
plt.savefig("_data/wind_scatter")

# %% [markdown]
# According to the data provided above a few trends are observed:
# *Latitude impacts the data results.
#
# *The highest temperatures are seen more near the equator and are decreasing going north and south of equator.
#
# *City Latitude vs. Humidity graph indicates that there is not a strong pattern observed, humidity is randomly dispersed. However there is a slightly larger cluster of northern hemisphere cities with high humidity (above 60% humidity).
#
# *There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities near 0, 80, and 90% cloudiness.
#
# *There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
